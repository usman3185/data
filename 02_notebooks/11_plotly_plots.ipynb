# %% [markdown]
# # plotly data visualization (part 1)

# %%
# # install plotly and kaleido
# !pip install plotly
# !pip install kaleido
# Out:
# Requirement already satisfied: plotly in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from plotly) (2.5.0)
# Requirement already satisfied: packaging in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from plotly) (25.0)
# Collecting kaleido
#   Downloading kaleido-1.1.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting choreographer>=1.0.10 (from kaleido)
#   Downloading choreographer-1.1.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting orjson>=3.10.15 (from kaleido)
#   Downloading orjson-3.11.3-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from kaleido) (25.0)
# Collecting pytest-timeout>=2.4.0 (from kaleido)
#   Downloading pytest_timeout-2.4.0-py3-none-any.whl.metadata (20 kB)
# Collecting simplejson>=3.19.3 (from choreographer>=1.0.10->kaleido)
#   Downloading simplejson-3.20.2-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting pytest>=7.0.0 (from pytest-timeout>=2.4.0->kaleido)
#   Downloading pytest-8.4.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama>=0.4 in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1 in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.3.0)
# Collecting iniconfig>=1 (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.19.2)
# Collecting tomli>=1 (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido)
#   Downloading tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\lenovo\miniconda3\envs\ydata_profiling\lib\site-packages (from exceptiongroup>=1->pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (4.15.0)
# Downloading kaleido-1.1.0-py3-none-any.whl (66 kB)
# Downloading choreographer-1.1.1-py3-none-any.whl (52 kB)
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading orjson-3.11.3-cp310-cp310-win_amd64.whl (131 kB)
# Downloading pytest_timeout-2.4.0-py3-none-any.whl (14 kB)
# Downloading pytest-8.4.2-py3-none-any.whl (365 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Downloading simplejson-3.20.2-cp310-cp310-win_amd64.whl (76 kB)
# Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: tomli, simplejson, pluggy, orjson, logistro, iniconfig, pytest, choreographer, pytest-timeout, kaleido
#
#    ---- -----------------------------------  1/10 [simplejson]
#    ---- -----------------------------------  1/10 [simplejson]
#    ---- -----------------------------------  1/10 [simplejson]
#    ---------------- -----------------------  4/10 [logistro]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ---------------------------- -----------  7/10 [choreographer]
#    ------------------------------------ ---  9/10 [kaleido]
#    ------------------------------------ ---  9/10 [kaleido]
#    ---------------------------------------- 10/10 [kaleido]
#
# Successfully installed choreographer-1.1.1 iniconfig-2.1.0 kaleido-1.1.0 logistro-1.1.0 orjson-3.11.3 pluggy-1.6.0 pytest-8.4.2 pytest-timeout-2.4.0 simplejson-3.20.2 tomli-2.2.1

# %%
# import libraries
import pandas as pd
import plotly.express as px
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
names =['usman', 'ali','ahmed','umer']
heights =[5,8,6,7]
# create a dataframe
# create a line plot
fig = px.line(x=names,y=heights,title='Heights of students')
fig.show()
#  save the plot as png file
fig.write_image('./03_outputs/line_plot.png')
# save as standalone html file
fig.write_html('./03_outputs/line_plot.html')

# %%
# creare a bar plot
px.bar(x=names,y=heights,title='Heights of students')

# %% [markdown]
# # plots on titanic dataset

# %%
# import titanic dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# scatter plot between two numeric variables
fig = px.scatter(df, x='age',y= 'fare' , color = 'sex' ,title='age vs fare')
fig.show()

# %%
df.dropna(inplace=True)
fig = px.scatter(df, x='age', y= 'fare' , color = 'sex', size='fare' ,title='plot of titanic dataset')
fig.show()
# save the plot
fig.write_image('D:/pandas_tips_tricks/02_notebooks/03_outputs.png',scale=3)

# %%
import plotly.graph_objects as go
# create a simple line chart
fig = go.Figure(data =go.Scatter(x=[1,2,3,4],y=[10,11,12,13]))
fig.show()

# %%
# customize the plot
fig.update_layout(
    title="Line plot of dummy data",
    xaxis_title="numbers",
    yaxis_title="values",
    showlegend=True
)
fig.show()
fig.show()

# %%
# heatmap on correlation of titanic dataset of age and fare
fig= px.imshow(df[['age','fare']].corr(),text_auto=True)
fig.show()
