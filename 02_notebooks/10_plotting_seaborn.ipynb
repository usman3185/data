# %% [markdown]
# # seaborn and plotting

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### important things for plotting according to grammar of graphics
# 1.Data (df)
# 2. types of plot
# 3. y axis
# 4. x axis
# 5. grouping (hue/color) based on categorical variable
# 6. size of plot
# 7. color pallets of the plot
# 8. style of the plot
# 9. how do you interept
# 10.

# %%
# data
df = sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# scatter plot
# scatter plot size of figure size
plt.figure(figsize=(12,8))
sns.scatterplot(data=df,x='age',y='fare',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot
# scatter plot size of figure size
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='age',y='fare',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot
# scatter plot size of figure size
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='age',y='fare',hue='sex')
# change the scatter point colors
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame
# df = your_dataframe

# Define custom colors for each hue level
custom_palette = {
    'male': 'blue',   # Color for males
    'female': 'pink'  # Color for females
}

plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=custom_palette)
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Sex')
plt.show()
# saving the plot 300dpi
plt.savefig('scatter_plot.png',dpi=300)
# saving the plot in vector file such as svg
plt.savefig('scatter_plot.svg')

# %%
# style of plot
sns.set_theme(style='darkgrid',font_scale=1.2)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame
# df = your_dataframe

# Define custom colors for each hue level
custom_palette = {
    'male': 'blue',   # Color for males
    'female': 'pink'  # Color for females
}

plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=custom_palette)
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Sex')
plt.show()

# %% [markdown]
# interpertation
# 1. we have age of passengers on x axisand fare at y axis
# 2. the scatter plot shows the relationship between age and fare
# 3. we further grouped the passengers by their genders such as male and female
# 4. two male passenger give the highest fare in titanic and might travel in first class
# 5. the oldest person at titanic is also male og age 80

# %% [markdown]
# # Boxplot

# %%
# style of plot
sns.set_theme(style='darkgrid',font_scale=1.2)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame# style of plot
sns.set_theme(style='darkgrid',font_scale=1.2)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame
# df = your_dataframe

# Define custom colors for each hue level
custom_palette = {
    'male': 'blue',   # Color for males
    'female': 'pink'  # Color for females
}

plt.figure(figsize=(10, 8))
sns.boxenplot(data=df, x='sex', y='age', hue='sex', palette=custom_palette)
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Sex')
# df = your_dataframe

# Define custom colors for each hue level
custom_palette = {
    'male': 'blue',   # Color for males
    'female': 'pink'  # Color for females
}

plt.figure(figsize=(10, 8))
sns.boxplot(data=df, x='sex', y='age', hue='sex', palette=custom_palette)
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Sex')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_55644\2943832946.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Sex')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_55644\2943832946.py:39: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Sex')

# %%
# change legend position and title
plt.legend(loc='lower right',title='Class Name')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_55644\1485564975.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='lower right',title='Class Name')

# %%
# style of plot
sns.set_theme(style='darkgrid',font_scale=1.2)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame
# df = your_dataframe

# Define custom colors for each hue level
custom_palette = {
    'male': 'blue',   # Color for males
    'female': 'pink'  # Color for females
}

plt.figure(figsize=(16, 6))
sns.scatterplot(data=df, x='age', y='fare', hue='sex',size = 'age' , palette=custom_palette)
plt.title('Scatter Plot of Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Sex')
plt.show()

# %%
# change the x ticks names 
plt.xticks(ticks=[0,1],labels=['Male','Female'],rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x25075496380>,
# ...
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
# import plotly
import plotly.express as px
fig = px.scatter(df,x='age',y= 'fare', color='sex')
fig.show()

# %%
# style of plot
sns.set_theme(style='darkgrid',font_scale=1.2)
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame
# df = your_dataframe
# Define custom colors for each hue level
custom_palette = {
    'First': 'blue',
    'Second': 'green',
    'Third': 'red'
}

plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='sex', y='age', hue='class' , palette= custom_palette)
plt.title('Barplot of age ,based on gender and class name of passengers')
plt.xlabel('Gender')
plt.ylabel('age')
plt.legend(title='Sex')
plt.show()
# add caps to the error bar
plt.errorbar(x= [0,1],y=[30,28],fmt='none',c='black',capsize=5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# add caps to the error bar
plt.errorbar(x= [0,1],y=[30,28],fmt='none',c='black',capsize=5)
# Out:
# <ErrorbarContainer object of 3 artists>
